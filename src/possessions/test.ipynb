# %%
from pathlib import Path
import pandas as pd

# Walk up until we find the repo root (folder containing .git)
root = Path.cwd()
while not (root / ".git").exists() and root != root.parent:
    root = root.parent

print("Using project root:", root)

df = pd.read_parquet(root / "data" / "processed" / "events.parquet")
df.head()
# Out:
# Using project root: d:\This PC\Documents\IIT\Final Year\dm-bypass
#    match_id         team_name                  player_name    type_name  \
# 0     15946         Barcelona                         None  Starting XI
# 1     15946  Deportivo Alavés                         None  Starting XI
# 2     15946         Barcelona                         None   Half Start
# 3     15946  Deportivo Alavés                         None   Half Start
# 4     15946  Deportivo Alavés  Jonathan Rodríguez Menéndez         Pass
#
#                timestamp  minute  second possession_team_name  period  \
# 0        0 days 00:00:00       0       0            Barcelona       1
# 1        0 days 00:00:00       0       0            Barcelona       1
# 2        0 days 00:00:00       0       0            Barcelona       1
# 3        0 days 00:00:00       0       0            Barcelona       1
# 4 0 days 00:00:00.575000       0       0     Deportivo Alavés       1
#
# ...
